# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from typing import TypedDict

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(model = 'gpt-4.1-mini')

# %%
# creating a state
class LLM_State(TypedDict):
    question: str
    answer: str

# %%
def llm_qa(state: LLM_State) -> LLM_State:

    # extract the question from state
    qustion = state['question']
    # form a prompt
    prompt = f'Answer the following qustion {qustion}'
    
    # ask the qustion
    ans = model.invoke(prompt).content
    # answer the state
    state['answer'] = ans
    return state

# %%
# now state is built we now need a graph
graph = StateGraph(LLM_State)

graph.add_node('llm_qaa', llm_qa)


graph.add_edge(START, 'llm_qaa')
graph.add_edge('llm_qaa', END)

workflow = graph.compile()

# %%
initial_state = {'question': 'How long should we do exercise for muscle build men?'}

final_state = workflow.invoke(initial_state)


print(final_state)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[47], line 3
#       1 initial_state = {'question': 'How long should we do exercise for muscle build men?'}
# ----> 3 final_state = workflow.invoke(initial_state)
#       6 print(final_state)
#
# File o:\LangGraph\myVenv\Lib\site-packages\langgraph\pregel\main.py:3071, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3068 chunks: list[dict[str, Any] | Any] = []
#    3069 interrupts: list[Interrupt] = []
# -> 3071 for chunk in self.stream(
#    3072     input,
#    3073     config,
#    3074     context=context,
#    3075     stream_mode=["updates", "values"]
#    3076     if stream_mode == "values"
#    3077     else stream_mode,
#    3078     print_mode=print_mode,
#    3079     output_keys=output_keys,
# ...
